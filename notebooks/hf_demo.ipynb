# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from tinygpt.config import setup_huggingface, setup_mlflow
# Out:
# 2025-11-28 01:39:01.694 | INFO     | tinygpt.config:<module>:12 - PROJ_ROOT path is: C:\importante\Master\Procesamiento lenguaje natural 2\Proyecto\TinyGPT

# %%
from tinygpt.config import setup_huggingface, setup_mlflow
import os

setup_huggingface(token=None)
setup_mlflow()
# Out:
# c:\importante\Master\Procesamiento lenguaje natural 2\Proyecto\TinyGPT\venv\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
